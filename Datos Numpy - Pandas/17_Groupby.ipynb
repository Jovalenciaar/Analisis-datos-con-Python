# %%
import pandas as pd
import numpy as np

# %%
car = pd.read_csv('C:/Users/Lenovo/Programacion/Base de datos/CarPricesPrediction.csv')
car.drop('Unnamed: 0', axis=1, inplace=True)
car.head(10)
# Out:
#         Make      Model  Year  Mileage  Condition     Price
# 0       Ford  Silverado  2022    18107  Excellent  19094.75
# 1     Toyota  Silverado  2014    13578  Excellent  27321.10
# 2  Chevrolet      Civic  2016    46054       Good  23697.30
# 3       Ford      Civic  2022    34981  Excellent  18251.05
# 4  Chevrolet      Civic  2019    63565  Excellent  19821.85
# 5       Ford  Silverado  2013    23600  Excellent  27820.00
# 6     Toyota     Altima  2014    11470  Excellent  27426.60
# 7  Chevrolet  Silverado  2015    89471       Good  22526.55
# 8       Ford      Camry  2014   121298       Good  21935.10
# 9       Ford     Altima  2016   110691  Excellent  20465.45

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sometimes we have some values duplicated in the dataframe, and we wanna sort or group these values to idenfity easier these values. So with the command "gruopby('columns')" we can do this.
#
# Or we can use the command "set_index("Indicate which index we want')

# %%
car.groupby('Make').count()
# Out:
#            Model  Year  Mileage  Condition  Price
# Make
# Chevrolet    209   209      209        209    209
# Ford         199   199      199        199    199
# Honda        199   199      199        199    199
# Nissan       188   188      188        188    188
# Toyota       205   205      205        205    205

# %%
car.set_index("Make")
# Out:
#                Model  Year  Mileage  Condition     Price
# Make
# Ford       Silverado  2022    18107  Excellent  19094.75
# Toyota     Silverado  2014    13578  Excellent  27321.10
# Chevrolet      Civic  2016    46054       Good  23697.30
# Ford           Civic  2022    34981  Excellent  18251.05
# Chevrolet      Civic  2019    63565  Excellent  19821.85
# ...              ...   ...      ...        ...       ...
# Nissan         Camry  2010   149032  Excellent  24548.50
# Chevrolet      F-150  2014    20608  Excellent  26969.70
# Ford          Altima  2016   109851       Good  20507.55
# Toyota     Silverado  2010    11704       Good  31414.90
# Nissan     Silverado  2017   128390  Excellent  18580.60
#
# [1000 rows x 5 columns]
