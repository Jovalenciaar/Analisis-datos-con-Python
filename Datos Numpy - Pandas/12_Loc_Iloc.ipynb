# %%
import pandas as pd

# %%
credito = pd.read_csv('C:/Users/Lenovo/Programacion/Base de datos/Tasas_de_inter_s_activas_por_tipo_de_cr_dito_20240219.csv')
credito.columns
# Out:
# Index(['Tipo_Entidad', 'Nombre_Tipo_Entidad', 'Codigo_Entidad',
#        'Nombre_Entidad', 'Fecha_Corte', 'Tipo_de_persona', 'Sexo',
#        'Tamaño_de_empresa', 'Tipo_de_crédito', 'Tipo_de_garantía',
#        'Producto de crédito', 'Plazo de crédito',
#        'Tasa_efectiva_promedio_ponderada', 'margen_adicional',
#        'Montos_desembolsados', 'Numero_de_creditos_desembolsados',
#        'Grupo_Etnico', 'Antiguedad_de_la_empresa', 'Tipo_de_Tasa',
#        'Rango_monto_desembolsado', 'Clase_deudor', 'Codigo_CIIU',
#        'Codigo_Municipio'],
#       dtype='object')

# %% [markdown]
#  As in Numpy we can identify each element in our CSV, we only need to wreite into [  ] wjt we want to indentify. Ex:

# %%
credito = pd.read_csv('C:/Users/Lenovo/Programacion/Base de datos/Tasas_de_inter_s_activas_por_tipo_de_cr_dito_20240219.csv', header = 0, names=['Tipo_Entidad', 'Nombre', 'Codigo_Entidad','Nombre_Entidad', 'Fecha_Corte', 'Tipo_de_persona', 'Sexo','Tamaño_de_empresa', 'Tipo_de_crédito', 'Tipo_de_garantía',
    'Producto de crédito', 'Plazo de crédito','Tasa_efectiva_promedio_ponderada', 'margen_adicional','Montos_desembolsados', 'Numero_de_creditos_desembolsados','Grupo_Etnico', 'Antiguedad_de_la_empresa', 'Tipo_de_Tasa','Rango_monto_desembolsado', 'Clase_deudor', 'Codigo_CIIU','Codigo_Municipio'])
credito.head(4)
# Out:
#    Tipo_Entidad                        Nombre  Codigo_Entidad  \
# 0            22  INSTITUCIÓN OFICIAL ESPECIAL               8
# 1             1   BC-ESTABLECIMIENTO BANCARIO               1
# 2             1   BC-ESTABLECIMIENTO BANCARIO               7
# 3             1   BC-ESTABLECIMIENTO BANCARIO               1
#
#               Nombre_Entidad Fecha_Corte Tipo_de_persona       Sexo  \
# 0  Fondo Nacional del Ahorro  27/10/2023         Natural  Masculino
# 1            Banco de Bogotá  17/11/2023         Natural  Masculino
# 2                Bancolombia  13/10/2023         Natural   Femenino
# 3            Banco de Bogotá  08/09/2023         Natural   Femenino
#
#   Tamaño_de_empresa Tipo_de_crédito             Tipo_de_garantía  ...  \
# 0         No aplica        Vivienda  Garantia idónea o no idónea  ...
# 1         No aplica        Vivienda  Garantia idónea o no idónea  ...
# 2         No aplica        Vivienda  Garantia idónea o no idónea  ...
# ...

# %%
credito['Nombre_Entidad']
# Out:
# 0        Fondo Nacional del Ahorro
# 1                  Banco de Bogotá
# 2                      Bancolombia
# 3                  Banco de Bogotá
# 4                    BBVA Colombia
#                    ...
# 54237              Banco de Bogotá
# 54238              Banco de Bogotá
# 54239             Banco Davivienda
# 54240                  Bancolombia
# 54241                  Bancolombia
# Name: Nombre_Entidad, Length: 54242, dtype: object

# %%
credito.loc[0:100]
# Out:
#      Tipo_Entidad                        Nombre  Codigo_Entidad  \
# 0              22  INSTITUCIÓN OFICIAL ESPECIAL               8
# 1               1   BC-ESTABLECIMIENTO BANCARIO               1
# 2               1   BC-ESTABLECIMIENTO BANCARIO               7
# 3               1   BC-ESTABLECIMIENTO BANCARIO               1
# 4               1   BC-ESTABLECIMIENTO BANCARIO              13
# ..            ...                           ...             ...
# 96              1   BC-ESTABLECIMIENTO BANCARIO               7
# 97              1   BC-ESTABLECIMIENTO BANCARIO               6
# 98              1   BC-ESTABLECIMIENTO BANCARIO              30
# 99              1   BC-ESTABLECIMIENTO BANCARIO               7
# 100             1   BC-ESTABLECIMIENTO BANCARIO               1
#
#                 Nombre_Entidad Fecha_Corte Tipo_de_persona       Sexo  \
# 0    Fondo Nacional del Ahorro  27/10/2023         Natural  Masculino
# ...

# %%
credito.loc[0:100, ['Nombre_Entidad', 'Tipo_de_crédito']]
# Out:
#                 Nombre_Entidad Tipo_de_crédito
# 0    Fondo Nacional del Ahorro        Vivienda
# 1              Banco de Bogotá        Vivienda
# 2                  Bancolombia        Vivienda
# 3              Banco de Bogotá        Vivienda
# 4                BBVA Colombia        Vivienda
# ..                         ...             ...
# 96                 Bancolombia        Vivienda
# 97                        Itaú        Vivienda
# 98      Banco Caja Social S.A.        Vivienda
# 99                 Bancolombia        Vivienda
# 100            Banco de Bogotá        Vivienda
#
# [101 rows x 2 columns]

# %% [markdown]
# We can sort our DataFrame with sort.value(), or sort.index().
#
# Now if we wanna modify the DataFrame definetly, we have to write inplace = True, of this way our file will be modifed definetly

# %%
credito.head(4)
# Out:
#    Tipo_Entidad                        Nombre  Codigo_Entidad  \
# 0            22  INSTITUCIÓN OFICIAL ESPECIAL               8
# 1             1   BC-ESTABLECIMIENTO BANCARIO               1
# 2             1   BC-ESTABLECIMIENTO BANCARIO               7
# 3             1   BC-ESTABLECIMIENTO BANCARIO               1
#
#               Nombre_Entidad Fecha_Corte Tipo_de_persona       Sexo  \
# 0  Fondo Nacional del Ahorro  27/10/2023         Natural  Masculino
# 1            Banco de Bogotá  17/11/2023         Natural  Masculino
# 2                Bancolombia  13/10/2023         Natural   Femenino
# 3            Banco de Bogotá  08/09/2023         Natural   Femenino
#
#   Tamaño_de_empresa Tipo_de_crédito             Tipo_de_garantía  ...  \
# 0         No aplica        Vivienda  Garantia idónea o no idónea  ...
# 1         No aplica        Vivienda  Garantia idónea o no idónea  ...
# 2         No aplica        Vivienda  Garantia idónea o no idónea  ...
# ...

# %%
credito.set_index('Nombre_Entidad', inplace=True)

# %%
credito.head(4)
# Out:
#                            Tipo_Entidad                        Nombre  \
# Nombre_Entidad
# Fondo Nacional del Ahorro            22  INSTITUCIÓN OFICIAL ESPECIAL
# Banco de Bogotá                       1   BC-ESTABLECIMIENTO BANCARIO
# Bancolombia                           1   BC-ESTABLECIMIENTO BANCARIO
# Banco de Bogotá                       1   BC-ESTABLECIMIENTO BANCARIO
#
#                            Codigo_Entidad Fecha_Corte Tipo_de_persona  \
# Nombre_Entidad
# Fondo Nacional del Ahorro               8  27/10/2023         Natural
# Banco de Bogotá                         1  17/11/2023         Natural
# Bancolombia                             7  13/10/2023         Natural
# Banco de Bogotá                         1  08/09/2023         Natural
#
#                                 Sexo Tamaño_de_empresa Tipo_de_crédito  \
# Nombre_Entidad
# Fondo Nacional del Ahorro  Masculino         No aplica        Vivienda
# ...

# %%
credito.sort_index(inplace=True)
credito.head(4)
# Out:
#                 Tipo_Entidad                       Nombre  Codigo_Entidad  \
# Nombre_Entidad
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
#
#                Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# Nombre_Entidad
# AV Villas       30/06/2023         Natural  Masculino         No aplica
# AV Villas       29/09/2023         Natural  Masculino         No aplica
# AV Villas       06/10/2023         Natural   Femenino         No aplica
# AV Villas       02/06/2023         Natural  Masculino         No aplica
#
#                Tipo_de_crédito             Tipo_de_garantía  \
# Nombre_Entidad
# AV Villas             Vivienda  Garantia idónea o no idónea
# AV Villas             Vivienda  Garantia idónea o no idónea
# ...

# %%
credito.loc['Bancolombia']
# Out:
#                 Tipo_Entidad                       Nombre  Codigo_Entidad  \
# Nombre_Entidad
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# ...                      ...                          ...             ...
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
# Bancolombia                1  BC-ESTABLECIMIENTO BANCARIO               7
#
# ...

# %% [markdown]
# ## Iloc nad Loc
#
# The difference between Loc and Iloc is by Loc we can filter by columns, while Iloc filter by rows Ex:

# %%
credito.head(4)
# Out:
#                 Tipo_Entidad                       Nombre  Codigo_Entidad  \
# Nombre_Entidad
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
#
#                Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# Nombre_Entidad
# AV Villas       30/06/2023         Natural  Masculino         No aplica
# AV Villas       29/09/2023         Natural  Masculino         No aplica
# AV Villas       06/10/2023         Natural   Femenino         No aplica
# AV Villas       02/06/2023         Natural  Masculino         No aplica
#
#                Tipo_de_crédito             Tipo_de_garantía  \
# Nombre_Entidad
# AV Villas             Vivienda  Garantia idónea o no idónea
# AV Villas             Vivienda  Garantia idónea o no idónea
# ...

# %%
credito.iloc[:2]
# Out:
#                 Tipo_Entidad                       Nombre  Codigo_Entidad  \
# Nombre_Entidad
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
# AV Villas                  1  BC-ESTABLECIMIENTO BANCARIO              49
#
#                Fecha_Corte Tipo_de_persona       Sexo Tamaño_de_empresa  \
# Nombre_Entidad
# AV Villas       30/06/2023         Natural  Masculino         No aplica
# AV Villas       29/09/2023         Natural  Masculino         No aplica
#
#                Tipo_de_crédito             Tipo_de_garantía  \
# Nombre_Entidad
# AV Villas             Vivienda  Garantia idónea o no idónea
# AV Villas             Vivienda  Garantia idónea o no idónea
#
#                                               Producto de crédito  ...  \
# Nombre_Entidad                                                     ...
# AV Villas       Adquisición de vivienda no vis (colocación en ...  ...
# AV Villas       Adquisición de vivienda no vis (colocación en ...  ...
#
# ...
