# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21936\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
car = pd.read_csv("C:/Users/Lenovo/Programacion/Base de datos/CarPricesPrediction.csv")
car.drop('Unnamed: 0', axis =1, inplace=True)
Honda = car['Make'] == "Honda"
Civic = car["Model"] == "Civic"
Hondacivid =car[Honda & Civic]
Hondacivid.sort_values(["Year"], ascending=True, inplace=True)
Hondacivid
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_21936\1042266520.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hondacivid.sort_values(["Year"], ascending=True, inplace=True)
#       Make  Model  Year  Mileage  Condition     Price
# 824  Honda  Civic  2010    47611  Excellent  29619.55
# 182  Honda  Civic  2010    29471  Excellent  30526.55
# 791  Honda  Civic  2010   147306       Good  24634.70
# 851  Honda  Civic  2011   112032  Excellent  25398.30
# 752  Honda  Civic  2011    77760       Good  27111.90
# 276  Honda  Civic  2011   117131       Good  25143.45
# 351  Honda  Civic  2011    51775  Excellent  28411.35
# 63   Honda  Civic  2012    99506  Excellent  25024.70
# 807  Honda  Civic  2012    48331  Excellent  27583.55
# 860  Honda  Civic  2014    10120  Excellent  27494.10
# ...

# %% [markdown]
# ## Info()
#
# With this command we can see all the info about our dataframe, like Index's number, Detail by columns, dtype.

# %%
Hondacivid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37 entries, 824 to 593
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Make       37 non-null     object
#  1   Model      37 non-null     object
#  2   Year       37 non-null     int64
#  3   Mileage    37 non-null     int64
#  4   Condition  37 non-null     object
#  5   Price      37 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.0+ KB

# %% [markdown]
# ## Descibe()
#
# We can see all kind of stad information such as mean, min, max, count, Std , by columns

# %%
Hondacivid.describe()
# Out:
#               Year        Mileage         Price
# count    37.000000      37.000000     37.000000
# mean   2016.216216   80076.918919  21779.972973
# std       3.916739   44631.973778   4522.788369
# min    2010.000000   10120.000000  12875.900000
# 25%    2014.000000   34734.000000  19133.500000
# 50%    2016.000000   84577.000000  20856.150000
# 75%    2019.000000  117131.000000  25143.450000
# max    2022.000000  147306.000000  30526.550000

# %% [markdown]
# ## Tail()
#
# Returns the last register in our dataframe

# %%
Hondacivid.tail(3)
# Out:
#       Make  Model  Year  Mileage  Condition    Price
# 49   Honda  Civic  2022    17332  Excellent  19133.5
# 582  Honda  Civic  2022   142482  Excellent  12875.9
# 593  Honda  Civic  2022    98546       Good  15072.7

# %% [markdown]
# ## Drop.duplicate()
#
# Eliminate the duplicated data in the dataframe. Ex:

# %%
new  = Hondacivid.loc[49]

# %%
pd.concat([Hondacivid, new])
# Out:
#             Make  Model    Year   Mileage  Condition     Price         49
# 824        Honda  Civic  2010.0   47611.0  Excellent  29619.55        NaN
# 182        Honda  Civic  2010.0   29471.0  Excellent  30526.55        NaN
# 791        Honda  Civic  2010.0  147306.0       Good  24634.70        NaN
# 851        Honda  Civic  2011.0  112032.0  Excellent  25398.30        NaN
# 752        Honda  Civic  2011.0   77760.0       Good  27111.90        NaN
# 276        Honda  Civic  2011.0  117131.0       Good  25143.45        NaN
# 351        Honda  Civic  2011.0   51775.0  Excellent  28411.35        NaN
# 63         Honda  Civic  2012.0   99506.0  Excellent  25024.70        NaN
# 807        Honda  Civic  2012.0   48331.0  Excellent  27583.55        NaN
# 860        Honda  Civic  2014.0   10120.0  Excellent  27494.10        NaN
# 787        Honda  Civic  2014.0   34734.0       Fair  26263.30        NaN
# 346        Honda  Civic  2014.0  131078.0       Fair  21446.20        NaN
# ...

# %%
Hondacivid.drop_duplicates()
# Out:
#       Make  Model  Year  Mileage  Condition     Price
# 824  Honda  Civic  2010    47611  Excellent  29619.55
# 182  Honda  Civic  2010    29471  Excellent  30526.55
# 791  Honda  Civic  2010   147306       Good  24634.70
# 851  Honda  Civic  2011   112032  Excellent  25398.30
# 752  Honda  Civic  2011    77760       Good  27111.90
# 276  Honda  Civic  2011   117131       Good  25143.45
# 351  Honda  Civic  2011    51775  Excellent  28411.35
# 63   Honda  Civic  2012    99506  Excellent  25024.70
# 807  Honda  Civic  2012    48331  Excellent  27583.55
# 860  Honda  Civic  2014    10120  Excellent  27494.10
# 787  Honda  Civic  2014    34734       Fair  26263.30
# 346  Honda  Civic  2014   131078       Fair  21446.20
# 641  Honda  Civic  2014    17168       Good  27141.60
# 341  Honda  Civic  2015   146704  Excellent  19664.90
# 777  Honda  Civic  2015   122879  Excellent  20856.15
# 280  Honda  Civic  2015   143862  Excellent  19806.90
# ...
