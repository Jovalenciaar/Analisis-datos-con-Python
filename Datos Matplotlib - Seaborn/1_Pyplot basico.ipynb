# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Matplolib.pyplto
#
# This library helps us to show or come up with new charts, we only need to wirte the command "plt.chart'sname", and following the command "plt.show()", the frist command creates the chart, either plot, pie, histrogram, and the second command shows the chart.
#
# Also, we have different way to create a chart in phyton, here, we cann see some examples of how made a chart. we cann add features ato our chart such as color, fomrs.

# %%
x = np.linspace(0,5,11)
y = x **2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'red')
plt.show()

# %%
plt.plot(x,y,'rs-')
plt.show()

# %% [markdown]
# ![cheatsheets-1.webp](attachment:cheatsheets-1.webp)
# ![cheatsheets-2.webp](attachment:cheatsheets-2.webp)
# ![handout-beginner.webp](attachment:handout-beginner.webp)
# ![handout-intermediate.webp](attachment:handout-intermediate.webp)
# ![handout-tips.webp](attachment:handout-tips.webp)
