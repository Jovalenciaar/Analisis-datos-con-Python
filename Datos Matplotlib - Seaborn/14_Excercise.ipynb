# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Lenovo/Programacion/Base de datos/Testing.csv')
df.head(4)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            9      120             72             22       56  20.8
# 1            1       71             62              0        0  21.8
# 2            8       74             70             40       49  35.3
# 3            5       88             78             30        0  27.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.733   48        0
# 1                     0.416   26        0
# 2                     0.705   39        0
# 3                     0.258   37        0

# %%
df.sort_values("Age", ascending=True)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 65             3       87             60             18        0  21.8
# 163            0       94             70             27      115  43.5
# 167            0      132             78              0        0  32.4
# 40             2      117             90             19       71  25.2
# 66             1       97             64             19       82  18.2
# ..           ...      ...            ...            ...      ...   ...
# 29             8      194             80              0        0  26.1
# 77             0       57             60              0        0  21.7
# 214            8       91             82              0        0  35.6
# 224            5      136             82              0        0   0.0
# 206            4      145             82             18        0  32.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 65                      0.444   21        0
# ...

# %%
filtro = df[["Insulin", "Age"]]
filtro.head(4)
# Out:
#    Insulin  Age
# 0       56   48
# 1        0   26
# 2       49   39
# 3        0   37

# %%
fig, ax = plt.subplots(figsize =(10,10))
ax.scatter(filtro["Age"], filtro["Insulin"])

# %%
sns.jointplot(data=filtro, x = "Age", y="Insulin")

# %%
dh = df[["Insulin", "Age", "Glucose"]]
dh
# Out:
#      Insulin  Age  Glucose
# 0         56   48      120
# 1          0   26       71
# 2         49   39       74
# 3          0   37       88
# 4          0   34      115
# ..       ...  ...      ...
# 303      180   63      101
# 304        0   27      122
# 305      112   30      121
# 306        0   47      126
# 307        0   23       93
#
# [308 rows x 3 columns]

# %%
sns.relplot(data=dh, x="Age", y="Glucose", hue="Insulin",alpha=0.9)
