# %%
import pandas as pd
import kit

# %%
df = pd.read_excel('C:/Users/Lenovo/Programacion/Python/BBDD/Libro2.xlsx', index_col=0)
df
# Out:
#                  CSI    STOXX      SPX   N225       IBOV  NIFTY
# Date
# 2021-09-30   992.000  4048.08  3715.28    229  17606.492    205
# 2021-10-29   997.000  4250.56  3968.12    219  15881.207    204
# 2021-11-30  1115.546  4063.06  4034.81    217  15985.914    200
# 2021-12-30  1109.388  4284.83  4220.12    221  16618.629    205
# 2022-01-31   984.000  4184.97  4007.10    209  18822.108    207
# 2022-02-28  1048.013  3829.29  3931.28    206  19452.238    198
# 2022-03-31   966.000  4002.18  4098.81    207  22886.596    208
# 2022-04-29   823.000  3734.64  3933.67    195  20582.702    212
# 2022-05-31   887.000  3808.86  3881.41    198  21929.849    199
# 2022-06-30   996.000  3549.29  3630.02    186  17885.834    191
# 2022-07-29  1033.412  3607.78  4025.23    204  19515.909    212
# 2022-08-31   974.000  3570.51  3977.27    201  21011.204    223
# 2022-09-30   879.000  3335.30  3649.86    183  20735.876    214
# 2022-10-31   872.000  3604.51  3921.39    188  22670.118    220
# ...

# %%
retornos =  df.pct_change().dropna()
retornos
# Out:
#                  CSI     STOXX       SPX      N225      IBOV     NIFTY
# Date
# 2021-10-29  0.005040  0.050019  0.068054 -0.043668 -0.097991 -0.004878
# 2021-11-30  0.118903 -0.044112  0.016806 -0.009132  0.006593 -0.019608
# 2021-12-30 -0.005520  0.054582  0.045928  0.018433  0.039580  0.025000
# 2022-01-31 -0.113024 -0.023305 -0.050477 -0.054299  0.132591  0.009756
# 2022-02-28  0.065054 -0.084990 -0.018921 -0.014354  0.033478 -0.043478
# 2022-03-31 -0.078256  0.045149  0.042615  0.004854  0.176553  0.050505
# 2022-04-29 -0.148033 -0.066849 -0.040290 -0.057971 -0.100666  0.019231
# 2022-05-31  0.077764  0.019873 -0.013285  0.015385  0.065450 -0.061321
# 2022-06-30  0.122886 -0.068149 -0.064768 -0.060606 -0.184407 -0.040201
# 2022-07-29  0.037562  0.016479  0.108873  0.096774  0.091138  0.109948
# 2022-08-31 -0.057491 -0.010330 -0.011915 -0.014706  0.076619  0.051887
# 2022-09-30 -0.097536 -0.065876 -0.082320 -0.089552 -0.013104 -0.040359
# ...

# %%
kit.ret_d(df, 12)
# Out:
# El retorno anualizado es: CSI     -0.096763
# STOXX    0.072968
# SPX      0.116835
#  N225    0.011512
# IBOV     0.072565
# NIFTY    0.105542
# dtype: float64
